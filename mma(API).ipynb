# %%
import requests
import pandas as pd
from sodapy import Socrata
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/scores/json/Schedule/UFC/2020'
params = {'key': 'e9a28bf04ba44009bebfcbf23c7a7160'}

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
schedule2020 = response.json()

# %%
schedule2020
# Out:
# [{'EventId': 103,
#   'LeagueId': 1,
#   'Name': 'UFC 246: McGregor vs. Cowboy',
#   'ShortName': 'UFC 246',
#   'Season': 2020,
#   'Day': '2020-01-18T00:00:00',
#   'DateTime': '2020-01-18T19:00:00',
#   'Status': 'Final',
#   'Active': True},
#  {'EventId': 104,
#   'LeagueId': 1,
#   'Name': 'UFC Fight Night: Blaydes vs. Dos Santos',
#   'ShortName': 'UFC Fight Night',
#   'Season': 2020,
#   'Day': '2020-01-25T00:00:00',
#   'DateTime': '2020-01-25T17:00:00',
#   'Status': 'Final',
#   'Active': True},
#  {'EventId': 105,
#   'LeagueId': 1,
#   'Name': 'UFC 247: Jones vs. Reyes',
#   'ShortName': 'UFC 247',
#   'Season': 2020,
#   'Day': '2020-02-08T00:00:00',
#   'DateTime': '2020-02-08T18:30:00',
#   'Status': 'Final',
#   'Active': True},
#  {'EventId': 106,
#   'LeagueId': 1,
#   'Name': 'UFC Fight Night: Anderson vs. Blachowicz 2',
#   'ShortName': 'UFC Fight Night',
#   'Season': 2020,
#   'Day': '2020-02-15T00:00:00',
#   'DateTime': '2020-02-15T17:00:00',
# ...

# %% [markdown]
# endpoints = 'https://api.sportsdata.io/v3/mma/scores/json/Schedule/UFC/2019'

# %% [markdown]
# response1 = requests.get(endpoints, params = params)

# %% [markdown]
# response1

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/scores/json/Event/51'

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
event51 = response.json()

# %%
event51
# Out:
# {'EventId': 51,
#  'LeagueId': 1,
#  'Name': 'UFC 245: Usman vs. Covington',
#  'ShortName': 'UFC 245',
#  'Season': 2019,
#  'Day': '2019-12-14T00:00:00',
#  'DateTime': '2019-12-14T18:15:00',
#  'Status': 'Final',
#  'Active': True,
#  'Fights': [{'FightId': 521,
#    'Order': 1,
#    'Status': 'Scheduled',
#    'WeightClass': None,
#    'CardSegment': None,
#    'Referee': None,
#    'Rounds': None,
#    'ResultClock': None,
#    'ResultRound': None,
#    'ResultType': 'Scrambled',
#    'WinnerId': None,
#    'Active': False,
#    'Fighters': []},
#   {'FightId': 1062,
#    'Order': 1,
#    'Status': 'Final',
#    'WeightClass': 'Welterweight',
#    'CardSegment': 'Main Card',
#    'Referee': 'Marc Goddard',
#    'Rounds': 5,
#    'ResultClock': 163,
#    'ResultRound': 2,
#    'ResultType': 'Scrambled',
#    'WinnerId': 140000145,
#    'Active': True,
#    'Fighters': [{'FighterId': 140000521,
#      'FirstName': 'Colby',
#      'LastName': 'Covington',
# ...

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/scores/json/Event/1'

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
event1 = response.json()

# %%
event1
# Out:
# {'EventId': 1,
#  'LeagueId': 1,
#  'Name': 'UFC Fight Night: Cejudo vs. Dillashaw',
#  'ShortName': 'UFC Fight Night',
#  'Season': 2019,
#  'Day': '2019-01-19T00:00:00',
#  'DateTime': '2019-01-19T18:00:00',
#  'Status': 'Final',
#  'Active': True,
#  'Fights': [{'FightId': 13,
#    'Order': 1,
#    'Status': 'Final',
#    'WeightClass': 'Flyweight',
#    'CardSegment': 'Main Card',
#    'Referee': 'Kevin MacDonald',
#    'Rounds': 5,
#    'ResultClock': 53,
#    'ResultRound': 3,
#    'ResultType': 'Scrambled',
#    'WinnerId': 140000026,
#    'Active': True,
#    'Fighters': [{'FighterId': 140000025,
#      'FirstName': 'TJ',
#      'LastName': 'Dillashaw',
#      'PreFightWins': None,
#      'PreFightLosses': None,
#      'PreFightDraws': None,
#      'PreFightNoContests': None,
#      'Winner': False,
#      'Moneyline': None,
#      'Active': True},
#     {'FighterId': 140000026,
#      'FirstName': 'Henry',
#      'LastName': 'Cejudo',
#      'PreFightWins': None,
# ...

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/scores/json/Fighter/140000098'

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
player_id140000098 = response.json()

# %%
player_id140000098
# Out:
# {'FighterId': 140000098,
#  'FirstName': 'Francis',
#  'LastName': 'Ngannou',
#  'Nickname': 'The Predator',
#  'WeightClass': 'Heavyweight',
#  'BirthDate': '1986-09-05T00:00:00',
#  'Height': 76.0,
#  'Weight': 263.0,
#  'Reach': 83.0,
#  'Wins': 16,
#  'Losses': 3,
#  'Draws': 0,
#  'NoContests': 0,
#  'TechnicalKnockouts': 13,
#  'TechnicalKnockoutLosses': 0,
#  'Submissions': 5,
#  'SubmissionLosses': 0,
#  'TitleWins': 1,
#  'TitleLosses': 1,
#  'TitleDraws': 0,
#  'CareerStats': {'FighterId': 140000098,
#   'FirstName': 'Francis',
#   'LastName': 'Ngannou',
#   'SigStrikesLandedPerMinute': 2.9,
#   'SigStrikeAccuracy': 48.9,
#   'TakedownAverage': 0.2,
#   'SubmissionAverage': 0.5,
#   'KnockoutPercentage': 50.4,
#   'TechnicalKnockoutPercentage': 50.4,
#   'DecisionPercentage': 0.0}}

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/scores/json/Fighters'

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
fighters = response.json()

# %%
print(fighters)
# Out:
# [{'FighterId': 140000001, 'FirstName': 'Chance', 'LastName': 'Rencountre', 'Nickname': 'Black Eagle', 'WeightClass': 'Welterweight', 'BirthDate': '1986-12-31T00:00:00', 'Height': 74.0, 'Weight': 170.0, 'Reach': 75.0, 'Wins': 14, 'Losses': 4, 'Draws': 0, 'NoContests': 0, 'TechnicalKnockouts': 14, 'TechnicalKnockoutLosses': 2, 'Submissions': 7, 'SubmissionLosses': 0, 'TitleWins': 0, 'TitleLosses': 0, 'TitleDraws': 0, 'CareerStats': {'FighterId': 140000001, 'FirstName': 'Chance', 'LastName': 'Rencountre', 'SigStrikesLandedPerMinute': 2.6, 'SigStrikeAccuracy': 31.7, 'TakedownAverage': 3.2, 'SubmissionAverage': 0.8, 'KnockoutPercentage': 0.0, 'TechnicalKnockoutPercentage': 0.0, 'DecisionPercentage': 13.3}}, {'FighterId': 140000002, 'FirstName': 'Kyle', 'LastName': 'Stewart', 'Nickname': 'Gunz Up', 'WeightClass': 'Welterweight', 'BirthDate': '1989-01-31T00:00:00', 'Height': 72.0, 'Weight': 170.0, 'Reach': 76.5, 'Wins': 13, 'Losses': 3, 'Draws': 0, 'NoContests': 0, 'TechnicalKnockouts': 14,
# ...

# %%
fighters[0]
# Out:
# {'FighterId': 140000001,
#  'FirstName': 'Chance',
#  'LastName': 'Rencountre',
#  'Nickname': 'Black Eagle',
#  'WeightClass': 'Welterweight',
#  'BirthDate': '1986-12-31T00:00:00',
#  'Height': 74.0,
#  'Weight': 170.0,
#  'Reach': 75.0,
#  'Wins': 14,
#  'Losses': 4,
#  'Draws': 0,
#  'NoContests': 0,
#  'TechnicalKnockouts': 14,
#  'TechnicalKnockoutLosses': 2,
#  'Submissions': 7,
#  'SubmissionLosses': 0,
#  'TitleWins': 0,
#  'TitleLosses': 0,
#  'TitleDraws': 0,
#  'CareerStats': {'FighterId': 140000001,
#   'FirstName': 'Chance',
#   'LastName': 'Rencountre',
#   'SigStrikesLandedPerMinute': 2.6,
#   'SigStrikeAccuracy': 31.7,
#   'TakedownAverage': 3.2,
#   'SubmissionAverage': 0.8,
#   'KnockoutPercentage': 0.0,
#   'TechnicalKnockoutPercentage': 0.0,
#   'DecisionPercentage': 13.3}}

# %%
fighter_df = pd.json_normalize(fighters)

# %%
fighter_df
# Out:
#       FighterId FirstName    LastName           Nickname    WeightClass  \
# 0     140000001    Chance  Rencountre        Black Eagle   Welterweight
# 1     140000002      Kyle     Stewart            Gunz Up   Welterweight
# 2     140000003     Geoff        Neal     Handz of Steel   Welterweight
# 3     140000004     Belal    Muhammad  Remember the Name   Welterweight
# 4     140000005    Dennis    Bermudez         The Menace  Featherweight
# ...         ...       ...         ...                ...            ...
# 1158  140001170     Bruno       Korea               None      Flyweight
# 1159  140001171      C.J.     Vergara               C.J.   Bantamweight
# 1160  140001172     Javid    Basharat   The Snow Leopard   Bantamweight
# 1161  140001173    Saimon    Oliveira               None   Bantamweight
# 1162  140001174     Chidi    Njokuani    Chidi Bang Bang   Middleweight
#
#                 BirthDate  Height  Weight  Reach  Wins  ...  \
# ...

# %%
fighter_df.to_csv(index = False)
# Out:
# "FighterId,FirstName,LastName,Nickname,WeightClass,BirthDate,Height,Weight,Reach,Wins,Losses,Draws,NoContests,TechnicalKnockouts,TechnicalKnockoutLosses,Submissions,SubmissionLosses,TitleWins,TitleLosses,TitleDraws,CareerStats.FighterId,CareerStats.FirstName,CareerStats.LastName,CareerStats.SigStrikesLandedPerMinute,CareerStats.SigStrikeAccuracy,CareerStats.TakedownAverage,CareerStats.SubmissionAverage,CareerStats.KnockoutPercentage,CareerStats.TechnicalKnockoutPercentage,CareerStats.DecisionPercentage,CareerStats\n140000001,Chance,Rencountre,Black Eagle,Welterweight,1986-12-31T00:00:00,74.0,170.0,75.0,14.0,4.0,0.0,0.0,14.0,2.0,7.0,0.0,0.0,0.0,0.0,140000001.0,Chance,Rencountre,2.6,31.7,3.2,0.8,0.0,0.0,13.3,\n140000002,Kyle,Stewart,Gunz Up,Welterweight,1989-01-31T00:00:00,72.0,170.0,76.5,13.0,3.0,0.0,0.0,14.0,0.0,7.0,2.0,0.0,2.0,0.0,140000002.0,Kyle,Stewart,3.4,54.3,3.1,0.0,0.0,0.0,0.0,\n140000003,Geoff,Neal,Handz of Steel,Welterweight,1990-08-28T00:00:00,71.0,171.0,75.0,13.0,4.0,0.0,
# ...

# %%
fighter_df.to_csv ('fighter_df.csv', index = False)

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/stats/json/Fight/1100'

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
fight1100 = response.json()

# %%
fight1100
# Out:
# {'FightId': 1100,
#  'Order': 10,
#  'Status': 'Scheduled',
#  'WeightClass': 'Lightweight',
#  'CardSegment': 'Main Card',
#  'Referee': None,
#  'Rounds': 3,
#  'ResultClock': 0,
#  'ResultRound': 0,
#  'ResultType': 'Scrambled',
#  'WinnerId': None,
#  'Active': False,
#  'FightStats': [{'FighterId': 140000165,
#    'FirstName': 'Beneil',
#    'LastName': 'Dariush',
#    'Winner': False,
#    'FantasyPoints': 0.0,
#    'FantasyPointsDraftKings': 0.0,
#    'Knockdowns': 0.0,
#    'TotalStrikesAttempted': 0.0,
#    'TotalStrikesLanded': 0.0,
#    'SigStrikesAttempted': 0.0,
#    'SigStrikesLanded': 0.0,
#    'TakedownsAttempted': 0.0,
#    'TakedownsLanded': 0.0,
#    'TakedownsSlams': 0.0,
#    'TakedownAccuracy': 0.0,
#    'Advances': 0.0,
#    'Reversals': 0.0,
#    'Submissions': 0.0,
#    'SlamRate': 0.0,
#    'TimeInControl': 0.0,
#    'FirstRoundWin': False,
#    'SecondRoundWin': False,
#    'ThirdRoundWin': False,
#    'FourthRoundWin': False,
#    'FifthRoundWin': False,
# ...

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/stats/json/Fight/1101'

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
fight1101 = response.json()

# %%
fight1101
# Out:
# {'FightId': 1101,
#  'Order': 7,
#  'Status': 'Final',
#  'WeightClass': 'Welterweight',
#  'CardSegment': 'Prelims',
#  'Referee': 'Keith Peterson',
#  'Rounds': 3,
#  'ResultClock': 175,
#  'ResultRound': 1,
#  'ResultType': 'Scrambled',
#  'WinnerId': 140000168,
#  'Active': True,
#  'FightStats': [{'FighterId': 140000035,
#    'FirstName': 'Thiago',
#    'LastName': 'Alves',
#    'Winner': False,
#    'FantasyPoints': 8.0,
#    'FantasyPointsDraftKings': 8.0,
#    'Knockdowns': 0.0,
#    'TotalStrikesAttempted': 28.8,
#    'TotalStrikesLanded': 14.4,
#    'SigStrikesAttempted': 28.8,
#    'SigStrikesLanded': 14.4,
#    'TakedownsAttempted': 0.0,
#    'TakedownsLanded': 0.0,
#    'TakedownsSlams': 0.0,
#    'TakedownAccuracy': 0.0,
#    'Advances': 0.0,
#    'Reversals': 0.0,
#    'Submissions': 0.0,
#    'SlamRate': 0.0,
#    'TimeInControl': 1.2,
#    'FirstRoundWin': False,
#    'SecondRoundWin': False,
#    'ThirdRoundWin': False,
#    'FourthRoundWin': False,
# ...

# %%
endpoint = 'https://api.sportsdata.io/v3/mma/stats/json/Fight/1102'

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
fight1102 = response.json()

# %%
fight1102
# Out:
# {'FightId': 1102,
#  'Order': 11,
#  'Status': 'Final',
#  'WeightClass': 'Welterweight',
#  'CardSegment': 'Early Prelims',
#  'Referee': 'Keith Peterson',
#  'Rounds': 3,
#  'ResultClock': 56,
#  'ResultRound': 1,
#  'ResultType': 'Scrambled',
#  'WinnerId': 140000048,
#  'Active': True,
#  'FightStats': [{'FighterId': 140000048,
#    'FirstName': 'Lyman',
#    'LastName': 'Good',
#    'Winner': True,
#    'FantasyPoints': 40.6,
#    'FantasyPointsDraftKings': 40.6,
#    'Knockdowns': 0.2,
#    'TotalStrikesAttempted': 64.8,
#    'TotalStrikesLanded': 33.3,
#    'SigStrikesAttempted': 61.1,
#    'SigStrikesLanded': 31.0,
#    'TakedownsAttempted': 0.0,
#    'TakedownsLanded': 0.0,
#    'TakedownsSlams': 0.0,
#    'TakedownAccuracy': 0.0,
#    'Advances': 0.0,
#    'Reversals': 0.0,
#    'Submissions': 0.0,
#    'SlamRate': 0.0,
#    'TimeInControl': 2.1,
#    'FirstRoundWin': False,
#    'SecondRoundWin': False,
#    'ThirdRoundWin': True,
#    'FourthRoundWin': False,
# ...
